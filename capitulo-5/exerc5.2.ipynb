# %%
frase = input("Digite uma frase: ")
palavras = frase.split()
nf = {x: x.replace("a", "o") for x in palavras}
print(nf)
# Out:
# Digite uma frase: banana tampa
# {'banana': 'bonono', 'tampa': 'tompo'}

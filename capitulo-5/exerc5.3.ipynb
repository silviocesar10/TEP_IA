# %%
numeros = range(11)
quadrados = {x: x**2 for x in numeros if x % 2 == 0}
print(quadrados)
# Out:
# {2: 1.4142135623730951, 4: 2.0, 6: 2.449489742783178, 8: 2.8284271247461903, 10: 3.1622776601683795}

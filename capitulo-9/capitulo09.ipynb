# %%
#9.20
import math

while True:
    try:
        numero = int(input("Digite um número inteiro: "))
        if numero < 0:
          raise Exception()
        else:
            raiz_quadrada = math.sqrt(numero)
            print(f"A raiz quadrada de {numero} é {raiz_quadrada:.2f}")
            break  # Sai do loop quando um número válido é inserido
    except Exception:
        print("Entrada inválida. Digite um número inteiro válido.")
# Out:
# Digite um número inteiro: -1
# Entrada inválida. Digite um número inteiro válido.
# Digite um número inteiro: 6
# A raiz quadrada de 6 é 2.45

# %%
#9.21
f = input("digite o nome do arquivo: ")
try:
  if(arquivo := open(f, 'r')):
    print("abriu")
  else:
    raise Exception()
except Exception as e:
     print("Arquivo nao encontrado")
# Out:
# digite o nome do arquivo: testet.txt
# Arquivo nao encontrado

# %%
#9.22
def calc_media(lst):
  try:
    if(len(lst) == 0):
      raise Exception()
  except Exception:
    print("Lista vazia")

calc_media([])
# Out:
# Lista vazia

# %%
#9.23
a = input("Digite o nome do arquivo: ")
f = open(a, 'r')
while(l := f.readlineif()):
  if(l.isdigit())

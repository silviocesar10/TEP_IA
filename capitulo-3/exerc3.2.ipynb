# %%
#i = 0
#while i <=100:
  #if (i % 2 == 0):
   # print(f"{i} e par")
  #i+=1
for i in range(1, 101):
  if (i % 2 == 0):
    print(f"{i} e par")
# Out:
# 2 e par
# 4 e par
# 6 e par
# 8 e par
# 10 e par
# 12 e par
# 14 e par
# 16 e par
# 18 e par
# 20 e par
# 22 e par
# 24 e par
# 26 e par
# 28 e par
# 30 e par
# 32 e par
# 34 e par
# 36 e par
# 38 e par
# 40 e par
# 42 e par
# 44 e par
# 46 e par
# 48 e par
# 50 e par
# 52 e par
# 54 e par
# 56 e par
# 58 e par
# 60 e par
# 62 e par
# 64 e par
# 66 e par
# 68 e par
# 70 e par
# 72 e par
# 74 e par
# 76 e par
# 78 e par
# 80 e par
# 82 e par
# 84 e par
# 86 e par
# 88 e par
# 90 e par
# 92 e par
# 94 e par
# 96 e par
# 98 e par
# 100 e par

# %%
it = 0
media = 0
while True:
  num = int(input("Digite um numero: \n"))
  if (num > 0):
    media += num
    it +=1
  else:
    break

res = media / it
print(f"{res}")
# Out:
# Digite um numero:
# 10
# Digite um numero:
# 10
# Digite um numero:
# 10
# Digite um numero:
# 10
# Digite um numero:
# -1
# 10.0

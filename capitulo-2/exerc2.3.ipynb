# %%
letra = input("Insira uma letra: \n")
letra = letra.lower()
if (letra == 'a' or letra == 'e' or letra == 'i' or letra == 'o' or letra == 'u'):
  print(f"A letra inserida {letra} e uma vogal")
else:
  print(f"A letra inserida {letra} e uma consoante")
# Out:
# Insira uma letra:
# f
# A letra inserida f e uma consoante

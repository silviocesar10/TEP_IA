# %%
texto = input("Insira uma palavra: \n")
reverse = texto[::-1]
if (texto == reverse):
  print(f"{texto} E um palindromo")
else:
  print(f"{texto} nao e um palindromo")
# Out:
# Insira uma palavra:
# SAIPPUAKIVIKAUPPIAS
# SAIPPUAKIVIKAUPPIAS E um palindromo

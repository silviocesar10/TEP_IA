# %%
num = int(input("Insira um numero: \n"))
if ((num % 2) == 0):
    print(f"Este numero {num} e par!")
else:
  print(f"Este numero {num} e impar!")
# Out:
# Insira um numero:
# 12
# Este numero 12 e par!

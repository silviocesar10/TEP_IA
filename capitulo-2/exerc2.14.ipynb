# %%
n1 = int(input("Digite um numero: \n"))
n2 = int(input("Digite um novo numero: \n"))
if (n1 % n2 == 0):
  print(f"O numero {n1} e divisivel por {n2}")
else:
  print(f"O numero {n1} nao e divisivel por {n2}")
# Out:
# Digite um numero:
# 10
# Digite um novo numero:
# 10
# O numero 10 e divisivel por 10

# %%
import nltk
nltk.download('punkt')
frase = input("Digite uma frase com 5 palavras: ")
palavras = nltk.word_tokenize(frase)
while len(palavras) < 5:
  frase = input("Digite uma frase com 5 palavras: ")
  palavras = nltk.word_tokenize(frase)

for p in palavras:
  print(p)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Digite uma frase com 5 palavras: b b b
# Digite uma frase com 5 palavras: b b v vmv v
# Digite uma frase com 5 palavras: v  v v v v v v v
# Digite uma frase com 5 palavras:  v v v v v v v v v v v v   v v v v v v v v v
# Digite uma frase com 5 palavras: bananana babcbababa babababa bababab abababa bababab
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9c28d0aaea72> in <cell line: 5>()
#       4 palavras = nltk.word_tokenize(frase)
#       5 while len(palavras) < 5:
# ----> 6   frase = input("Digite uma frase com 5 palavras: ")
#       7
#       8 palavras = nltk.word_tokenize(frase)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

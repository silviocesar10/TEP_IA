# %%
import nltk
nltk.download('punkt')
frase = input("Digite uma frase: ")
palavras = nltk.word_tokenize(frase)
o = 0
a = 0
for s in palavras:
  if s.endswith("o"):
      o += 1
  if s.endswith("a"):
      a +=1
print(f"{o} terminam com o e {a} terminam com a")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Digite uma frase: macaco carro banana tampa
# 2 terminam com o e 2 terminam com a

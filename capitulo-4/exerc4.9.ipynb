# %%
frase = input("Digite uma frase: ")
pr = input("Digite uma palavra presente na frase ")
au = input("Digite uma palavra ausente na frase ")
texto = frase.replace(pr,au)
print(texto)
# Out:
# Digite uma frase: Aqui tem banana
# Digite uma palavra presente na frase banana
# Digite uma palavra ausente na frase pera
# Aqui tem pera

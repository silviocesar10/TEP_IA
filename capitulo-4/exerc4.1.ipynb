# %%
import math

n1 = float(input("Digite um numero: "))
n2 = float(input("Digite um outro numero: "))
print(f"O resultado da potencia e {math.pow(n1,n2)}")
# Out:
# Digite um numero2
# Digite um outro numero2
# O resultado da potencia e 4.0

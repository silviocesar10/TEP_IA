# %%
import math
ang = int(input("Por favor insira o angulo em graus: "))
print(f"O seno eh {math.sin(ang)}")
print(f"O cosseno eh {math.cos(ang)}")
print(f"A tangente eh {math.tan(ang)}")
# Out:
# Por favor insira o angulo em graus: 25

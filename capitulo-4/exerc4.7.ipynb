# %%
import re
nome = input("Digite o seu nome ")
senha = input("Digite uma senha alfanumerica ")
senha = re.sub('[^A-Za-z0-9]+', ' ', senha)
print(senha)
# Out:
# Digite o seu nome silvio
# Digite uma senha alfanumerica asdjao(*&(*LH(*A8798(S*A(*(*¨#&#
# asdjao LH A8798 S A

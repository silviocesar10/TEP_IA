# %%
frase = input("Digite uma frase: ")
p = set(frase.split())
#last =[]
#for s in p:
 # if s in last:
  #  continue
  #last.append(s)

#for s in last:
 # print(f"A palavra {s} {frase.count(s)}")
 for s in p:
  print(f"A palavra {s} {frase.count(s)}")
# Out:
#   File "<ipython-input-1-1b4beefd0fea>", line 11
#     for s in p:
#     ^
# IndentationError: unexpected indent

# %%
nome = None
preco_custo = None
preco_venda = None
estoque = None
nome = str(input("Por favor insiria o nome do produto: \n"))
preco_custo = float(input("Por favor insiria o preco de custo do produto: \n"))
preco_venda = float(input("Por favor insiria o preco de venda do produto: \n"))
estoque = int(input("Por favor insiria a quantidade do produto em estoque: \n"))
lucro = (preco_venda * estoque) - (preco_custo * estoque)
print(f"\n o lucro sera de : {lucro}")
# Out:
# Por favor insiria o nome do produto:
# banana
# Por favor insiria o preco de custo do produto:
# 2.5
# Por favor insiria o preco de venda do produto:
# 3.5
# Por favor insiria a quantidade do produto em estoque:
# 150
#
#  o lucro sera de : 150.0

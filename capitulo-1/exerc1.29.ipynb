# %%
familia1 = {"nome" : "Fulano", "idade": "22", "olhos" : "verdes"}
familia2 = {"nome" : "Siclano", "idade": "26", "olhos" : "rosa"}
familia3 = {"nome" : "Beltrano", "idade": "12", "olhos" : "azuis"}
familia4 = {"nome" : "Ze", "idade": "22", "olhos" : "verdes"}
familia5 = {"nome" : "Jao", "idade": "24", "olhos" : "verdes"}
familia = [familia1,familia2,familia3,familia4,familia5]
print(familia)
# Out:
# [{'nome': 'Fulano', 'idade': '22', 'olhos': 'verdes'}, {'nome': 'Siclano', 'idade': '26', 'olhos': 'rosa'}, {'nome': 'Beltrano', 'idade': '12', 'olhos': 'azuis'}, {'nome': 'Ze', 'idade': '22', 'olhos': 'verdes'}, {'nome': 'Jao', 'idade': '24', 'olhos': 'verdes'}]

# %%
conj1={1,2,3,4,5}
conj2={2,3,5,7,11}
uniao = conj1 | conj2
inter = conj1 & conj2
excl = conj1 ^ conj2
subt = conj1 - conj2
print(uniao)
print(inter)
print(excl)
print(subt)
# Out:
# {1, 2, 3, 4, 5, 7, 11}
# {2, 3, 5}
# {1, 4, 7, 11}
# {1, 4}
